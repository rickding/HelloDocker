# %%
import logging

log = logging.getLogger(__name__)

log.warning("Hello World from Jupyter Notebook!")
# Out:
# Hello World from Jupyter Notebook!

# %%
import keras

help(keras)
# Out:
# Using TensorFlow backend.
# Help on package keras:
#
# NAME
#     keras
#
# PACKAGE CONTENTS
#     activations
#     applications (package)
#     backend (package)
#     callbacks
#     constraints
#     datasets (package)
#     engine (package)
#     initializers
#     layers (package)
#     legacy (package)
#     losses
#     metrics
#     models
#     objectives
#     optimizers
#     preprocessing (package)
#     regularizers
#     utils (package)
#     wrappers (package)
#
# DATA
#     absolute_import = _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0...
#
# VERSION
#     2.2.4
#
# FILE
#     /opt/conda/lib/python3.6/site-packages/keras/__init__.py
